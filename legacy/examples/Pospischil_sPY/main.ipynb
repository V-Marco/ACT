# %% [markdown]
# # Pospischil sPY Example

# %% [markdown]
# ### Install dependencies for ACT

# %%
# !pip install act-neuron
# Out:
# Requirement already satisfied: act-neuron in /home/tyler/neuro-venv/lib/python3.10/site-packages (0.0.9)
# Requirement already satisfied: neuron>=8.2.0 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from act-neuron) (8.2.2)
# Requirement already satisfied: numpy in /home/tyler/neuro-venv/lib/python3.10/site-packages (from act-neuron) (1.25.1)
# Requirement already satisfied: matplotlib in /home/tyler/neuro-venv/lib/python3.10/site-packages (from act-neuron) (3.7.2)
# Requirement already satisfied: torch in /home/tyler/neuro-venv/lib/python3.10/site-packages (from act-neuron) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from matplotlib->act-neuron) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from matplotlib->act-neuron) (4.41.1)
# Requirement already satisfied: cycler>=0.10 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from matplotlib->act-neuron) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from matplotlib->act-neuron) (10.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from matplotlib->act-neuron) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from matplotlib->act-neuron) (1.1.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from matplotlib->act-neuron) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from matplotlib->act-neuron) (1.4.4)
# Requirement already satisfied: jinja2 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (3.1.2)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (8.5.0.96)
# Requirement already satisfied: networkx in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (3.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (11.7.101)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (10.2.10.91)
# Requirement already satisfied: sympy in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (1.12)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (11.4.0.1)
# Requirement already satisfied: typing-extensions in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (4.7.1)
# Requirement already satisfied: filelock in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (3.12.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (11.7.99)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (2.0.0)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (10.9.0.58)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from torch->act-neuron) (11.7.4.91)
# Requirement already satisfied: setuptools in /home/tyler/neuro-venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->act-neuron) (68.0.0)
# Requirement already satisfied: wheel in /home/tyler/neuro-venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->act-neuron) (0.41.0)
# Requirement already satisfied: cmake in /home/tyler/neuro-venv/lib/python3.10/site-packages (from triton==2.0.0->torch->act-neuron) (3.27.0)
# Requirement already satisfied: lit in /home/tyler/neuro-venv/lib/python3.10/site-packages (from triton==2.0.0->torch->act-neuron) (16.0.6)
# Requirement already satisfied: six>=1.5 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->act-neuron) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from jinja2->torch->act-neuron) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/tyler/neuro-venv/lib/python3.10/site-packages (from sympy->torch->act-neuron) (1.3.0)

# %% [markdown]
# ### Setup base directory and download cells

# %%
import sys

# Download the repository with all relevant model files if in google colab
IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    # !rm -rf ./ACT
    # !git clone https://github.com/V-Marco/ACT
    base_dir = "./ACT"
else:
    base_dir = "../.."

# %% [markdown]
# ### Define a config file
#
# These settings are modifiable by the user of ACT. Tune your own cells by altering values here.

# %%
import os

import numpy as np

pospischilsPY = {
    "cell": {
        "hoc_file": "../data/Pospischil/sPy/template.hoc",
        "modfiles_folder": "../data/Pospischil/sPy/seg_modfiles",
        "name": "sPY",
    },
    "simulation_parameters": {
        "h_v_init": -67.0,  # (mV)
        "h_tstop": 2000,  # (ms)
        "h_i_delay": 500,  # (ms)
        "h_i_dur": 1500,  # (ms)
        "h_dt": 0.025,
    },
    "optimization_parameters": {
        "amps": list(np.arange(-2, 10, 0.1)),
        "params": [
            {"channel": "g_pas", "low": 5.0e-06, "high": 2.0e-05},
            {"channel": "gnabar_hh2", "low": 2.5e-02, "high": 1.0e-01},
            {"channel": "gkbar_hh2", "low": 2.5e-03, "high": 1.0e-02},
            {"channel": "gkbar_im", "low": 1.5e-05, "high": 6.0e-05},
        ],
        "target_V": None,  # Target voltages
        "target_params": [0.0001, 0.05, 0.005, 7e-5],
        "num_repeats": 3,
        "num_amps_to_match": 12,
        "num_epochs": 5000,
    },
    "summary_features": {
        "spike_threshold": 20,  # (mV)
        # Target-sim match conditions (max abs diff between sim and target)
        "mc_num_spikes": 1,
        "mc_interspike_time": 200,  # (ms)
        "mc_min_v": 1,  # (mV)
        "mc_mean_v": 2,  # (mV)
        "mc_max_v": 1,  # (mV)
    },
    "segregation": [
        {
            "params": ["g_pas"],
            "voltage": [-100, -65],
            "time": [0, 500],
        },
        {
            "params": ["gnabar_hh2", "gkbar_hh2", "gkbar_im"],
            "voltage": [-65, 100],
            "time": [0, 2000],
        },
    ],
    "output": {"folder": "output_Pospischil_sPY", "produce_plots": True},
    "run_mode": "segregated",  # "original", "segregated"
}

# %% [markdown]
# ### Run the simulation

# %%
from act import simulator, analysis

simulator.run(pospischilsPY)
# Out:
# /home/tyler/neuro-venv/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# Translating cadecay_destexhe.mod into /home/tyler/git_stage/ACT/examples/Pospischil_sPYr/x86_64/cadecay_destexhe.c
# Translating HH_traub.mod into /home/tyler/git_stage/ACT/examples/Pospischil_sPYr/x86_64/HH_traub.c
# Translating IM_cortex.mod into /home/tyler/git_stage/ACT/examples/Pospischil_sPYr/x86_64/IM_cortex.c
# Notice: VERBATIM blocks are not thread safe
# Thread Safe
# Notice: This mechanism cannot be used with CVODE
# Thread Safe
# Translating IT_huguenard.mod into /home/tyler/git_stage/ACT/examples/Pospischil_sPYr/x86_64/IT_huguenard.c
# Thread Safe
# /home/tyler/git_stage/ACT/examples/Pospischil_sPYr
# Mod files: "../../data/Pospischil/sPyr/seg_modfiles/../../data/Pospischil/sPyr/seg_modfiles/cadecay_destexhe.mod" "../../data/Pospischil/sPyr/seg_modfiles/../../data/Pospischil/sPyr/seg_modfiles/HH_traub.mod" "../../data/Pospischil/sPyr/seg_modfiles/../../data/Pospischil/sPyr/seg_modfiles/IM_cortex.mod" "../../data/Pospischil/sPyr/seg_modfiles/../../data/Pospischil/sPyr/seg_modfiles/IT_huguenard.mod"
#
# Creating 'x86_64' directory for .o files.
#
#  -> Compiling mod_func.cpp
#  -> NMODL ../../../data/Pospischil/sPyr/seg_modfiles/cadecay_destexhe.mod
#  -> NMODL ../../../data/Pospischil/sPyr/seg_modfiles/HH_traub.mod
#  -> NMODL ../../../data/Pospischil/sPyr/seg_modfiles/IM_cortex.mod
# Warning: Default 36 of PARAMETER celsius will be ignored and set by NEURON.
# Warning: Default 36 of PARAMETER celsius will be ignored and set by NEURON.
# Warning: Default -90 of PARAMETER ek will be ignored and set by NEURON.
# Warning: Default 50 of PARAMETER ena will be ignored and set by NEURON.
#  -> NMODL ../../../data/Pospischil/sPyr/seg_modfiles/IT_huguenard.mod
#  -> Compiling cadecay_destexhe.c
#  -> Compiling IM_cortex.c
# Warning: Default 36 of PARAMETER celsius will be ignored and set by NEURON.
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 0.00024 of PARAMETER cai will be ignored and set by NEURON.
#  -> Compiling HH_traub.c
#  -> Compiling IT_huguenard.c
#  => LINKING shared library ./libnrnmech.so
#  => LINKING executable ./special LDFLAGS are:    -pthread
# Successfully created x86_64/special
# INFO : Using neuron-nightly Package (Developer Version)
#
# (2023-09-02 11:20:10.905128)-[START]
# (2023-09-02 11:20:10.905171)-[INFO]: Number of amplitudes: 120
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# (2023-09-02 11:20:45.865256)-[INFO]: Target voltage shape: torch.Size([120, 80000])
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# (2023-09-02 11:20:45.933012)-[INFO]: Matching 12 amplitudes.
# (2023-09-02 11:21:21.799817)-[INFO]: Total amplitudes matched: 6/12.
# (2023-09-02 11:21:55.533570)-[INFO]: Total amplitudes matched: 15/12.
# (2023-09-02 11:21:55.545624)-[INFO]: Matched amplitudes: [-0.1  0.4  1.3  1.6  1.7  1.8  2.1  2.8  2.9  3.   4.4  4.5  6.3  8.3
#   9.5]
# (2023-09-02 11:21:55.819778)-[INFO]: Training a model with SGD optimizer and lr = 1e-8.
# (2023-09-02 11:21:55.819891)-[INFO]: Number of trainable parameters: 20546305
# (2023-09-02 11:21:55.829651)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:55.926175)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:21:55.975618)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.032540)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.088624)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.144871)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.200836)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.257672)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.313420)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.369275)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.428004)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.484544)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.543261)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:56.599157)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:21:56.655659)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:21:57.026370)-[INFO]: Training a model with SGD optimizer and lr = 1e-8.
# (2023-09-02 11:21:57.026461)-[INFO]: Number of trainable parameters: 20547076
# (2023-09-02 11:21:57.029994)-[EPOCH 0]: l1_loss = 0.00234
# (2023-09-02 11:22:01.892914)-[EPOCH 0]: l1_loss = 0.00449
# (2023-09-02 11:22:01.948865)-[EPOCH 0]: l1_loss = 0.00825
# (2023-09-02 11:22:02.004056)-[EPOCH 0]: l1_loss = 0.00456
# (2023-09-02 11:22:07.072797)-[EPOCH 100]: l1_loss = 0.00146
# (2023-09-02 11:22:07.636216)-[EPOCH 0]: l1_loss = 0.01091
# (2023-09-02 11:22:07.691775)-[EPOCH 0]: l1_loss = 0.00313
# (2023-09-02 11:22:07.746853)-[EPOCH 0]: l1_loss = 0.01449
# (2023-09-02 11:22:07.802110)-[EPOCH 0]: l1_loss = 0.00843
# (2023-09-02 11:22:07.858182)-[EPOCH 0]: l1_loss = 0.01011
# (2023-09-02 11:22:12.927842)-[EPOCH 100]: l1_loss = 0.00619
# (2023-09-02 11:22:15.415755)-[EPOCH 0]: l1_loss = 0.01275
# (2023-09-02 11:22:20.561179)-[EPOCH 100]: l1_loss = 0.01253
# (2023-09-02 11:22:25.934700)-[EPOCH 200]: l1_loss = 0.01215
# (2023-09-02 11:22:31.198077)-[EPOCH 300]: l1_loss = 0.01104
# (2023-09-02 11:22:36.483977)-[EPOCH 400]: l1_loss = 0.00675
# (2023-09-02 11:22:39.850223)-[EPOCH 0]: l1_loss = 0.00912
# (2023-09-02 11:22:39.908445)-[EPOCH 0]: l1_loss = 0.00645
# (2023-09-02 11:22:39.969084)-[EPOCH 0]: l1_loss = 0.00311
# (2023-09-02 11:22:42.715986)-[EPOCH 0]: l1_loss = 0.00104
# (2023-09-02 11:22:42.931935)-[EPOCH 0]: l1_loss = 0.01291
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# (2023-09-02 11:23:21.403048)-[INFO]: Matching 12 amplitudes.
# (2023-09-02 11:24:05.988167)-[INFO]: Total amplitudes matched: 5/12.
# (2023-09-02 11:24:40.364798)-[INFO]: Total amplitudes matched: 9/12.
# (2023-09-02 11:25:12.779997)-[INFO]: Total amplitudes matched: 14/12.
# (2023-09-02 11:25:12.783542)-[INFO]: Matched amplitudes: [0.8 1.4 2.1 2.5 3.1 3.3 3.7 4.  6.  6.2 6.6 7.5 8.4 9.9]
# (2023-09-02 11:25:13.017362)-[INFO]: Training a model with SGD optimizer and lr = 1e-8.
# (2023-09-02 11:25:13.017462)-[INFO]: Number of trainable parameters: 20546305
# (2023-09-02 11:25:13.021147)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:25:13.050951)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:25:13.102669)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:25:13.158006)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:25:13.213671)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:25:13.272903)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:25:13.328538)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:25:13.384042)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:25:13.439713)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:25:13.498621)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:25:13.556821)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:25:13.612347)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:25:13.668146)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:25:13.726903)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:25:14.076456)-[INFO]: Training a model with SGD optimizer and lr = 1e-8.
# (2023-09-02 11:25:14.076568)-[INFO]: Number of trainable parameters: 20547076
# (2023-09-02 11:25:14.080127)-[EPOCH 0]: l1_loss = 0.0161
# (2023-09-02 11:25:14.109052)-[EPOCH 0]: l1_loss = 0.01311
# (2023-09-02 11:25:14.160063)-[EPOCH 0]: l1_loss = 0.01008
# (2023-09-02 11:25:19.379995)-[EPOCH 100]: l1_loss = 0.00876
# (2023-09-02 11:25:24.629419)-[EPOCH 200]: l1_loss = 0.00279
# (2023-09-02 11:25:25.663021)-[EPOCH 0]: l1_loss = 0.00245
# (2023-09-02 11:25:25.719221)-[EPOCH 0]: l1_loss = 0.01089
# (2023-09-02 11:25:30.934386)-[EPOCH 100]: l1_loss = 0.01038
# (2023-09-02 11:25:36.169315)-[EPOCH 200]: l1_loss = 0.00844
# (2023-09-02 11:25:41.409246)-[EPOCH 300]: l1_loss = 0.00201
# (2023-09-02 11:25:41.724920)-[EPOCH 0]: l1_loss = 0.01092
# (2023-09-02 11:25:47.034150)-[EPOCH 100]: l1_loss = 0.00998
# (2023-09-02 11:25:52.287548)-[EPOCH 200]: l1_loss = 0.00606
# (2023-09-02 11:25:55.195644)-[EPOCH 0]: l1_loss = 0.01086
# (2023-09-02 11:25:55.252730)-[EPOCH 0]: l1_loss = 0.01268
# (2023-09-02 11:25:55.310867)-[EPOCH 0]: l1_loss = 0.00453
# (2023-09-02 11:25:55.367608)-[EPOCH 0]: l1_loss = 0.0013
# (2023-09-02 11:25:55.426471)-[EPOCH 0]: l1_loss = 0.00098
# (2023-09-02 11:25:55.482193)-[EPOCH 0]: l1_loss = 0.00615
# (2023-09-02 11:25:55.538723)-[EPOCH 0]: l1_loss = 0.00732
# (2023-09-02 11:25:55.595731)-[EPOCH 0]: l1_loss = 0.00798
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# (2023-09-02 11:26:34.042839)-[INFO]: Matching 12 amplitudes.
# (2023-09-02 11:27:10.555302)-[INFO]: Total amplitudes matched: 6/12.
# (2023-09-02 11:27:44.618299)-[INFO]: Total amplitudes matched: 12/12.
# (2023-09-02 11:27:44.622330)-[INFO]: Matched amplitudes: [0.6 0.9 1.4 1.5 3.7 7.1 7.3 7.4 8.4 9.2 9.3 9.7]
# (2023-09-02 11:27:44.869862)-[INFO]: Training a model with SGD optimizer and lr = 1e-8.
# (2023-09-02 11:27:44.869998)-[INFO]: Number of trainable parameters: 20546305
# (2023-09-02 11:27:44.873847)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:27:44.909541)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:27:44.965575)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:27:45.024582)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:27:45.092809)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:27:45.151556)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:27:45.209161)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:27:45.270601)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:27:45.333440)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:27:45.391787)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:27:45.447027)-[EPOCH 0]: l1_loss = 1e-05
# (2023-09-02 11:27:45.506795)-[EPOCH 0]: l1_loss = 0.0
# (2023-09-02 11:27:45.869848)-[INFO]: Training a model with SGD optimizer and lr = 1e-8.
# (2023-09-02 11:27:45.869955)-[INFO]: Number of trainable parameters: 20547076
# (2023-09-02 11:27:45.875364)-[EPOCH 0]: l1_loss = 0.00774
# (2023-09-02 11:27:51.230539)-[EPOCH 100]: l1_loss = 0.00424
# (2023-09-02 11:27:53.666317)-[EPOCH 0]: l1_loss = 0.00707
# (2023-09-02 11:27:58.950065)-[EPOCH 100]: l1_loss = 0.00244
# (2023-09-02 11:28:00.175015)-[EPOCH 0]: l1_loss = 0.01872
# (2023-09-02 11:28:05.637960)-[EPOCH 100]: l1_loss = 0.01853
# (2023-09-02 11:28:10.922730)-[EPOCH 200]: l1_loss = 0.01805
# (2023-09-02 11:28:16.080241)-[EPOCH 300]: l1_loss = 0.01656
# (2023-09-02 11:28:21.244791)-[EPOCH 400]: l1_loss = 0.01015
# (2023-09-02 11:28:26.084702)-[EPOCH 0]: l1_loss = 0.00305
# (2023-09-02 11:28:29.865461)-[EPOCH 0]: l1_loss = 0.01194
# (2023-09-02 11:28:29.924196)-[EPOCH 0]: l1_loss = 0.00092
# (2023-09-02 11:28:29.979567)-[EPOCH 0]: l1_loss = 0.00832
# (2023-09-02 11:28:30.035055)-[EPOCH 0]: l1_loss = 0.0146
# (2023-09-02 11:28:30.094723)-[EPOCH 0]: l1_loss = 0.00575
# (2023-09-02 11:28:35.255638)-[EPOCH 100]: l1_loss = 0.00259
# (2023-09-02 11:28:36.556057)-[EPOCH 0]: l1_loss = 0.00483
# (2023-09-02 11:28:36.615624)-[EPOCH 0]: l1_loss = 0.01101
# (2023-09-02 11:28:36.672227)-[EPOCH 0]: l1_loss = 0.01201
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# Skipping analytical setting of passive properties, no cell passive_properties specified in config.
# output_Pospischil_sPYr : segregated
# Med MSE: 1762.6290 (11269.1092)
# Med Corr: 0.5394 (0.2470)
# Pred MAE: 0.0041
# ----------

# %%
from IPython.display import Image

Image(filename="./output_Pospischil_sPY/segregated/1000nA.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 from IPython.display import Image
# ----> 2 Image(filename='./output_Pospischil_sPY/1000nA.png')
#
# File ~/neuro-venv/lib/python3.10/site-packages/IPython/core/display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File ~/neuro-venv/lib/python3.10/site-packages/IPython/core/display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
#     328 self._check_data()
#
# File ~/neuro-venv/lib/python3.10/site-packages/IPython/core/display.py:1005, in Image.reload(self)
#    1003 """Reload the raw data from file or URL."""
#    1004 if self.embed:
# -> 1005     super(Image,self).reload()
#    1006     if self.retina:
#    1007         self._retina_shape()
#
# File ~/neuro-venv/lib/python3.10/site-packages/IPython/core/display.py:353, in DisplayObject.reload(self)
#     351 if self.filename is not None:
#     352     encoding = None if "b" in self._read_flags else "utf-8"
# --> 353     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     354         self.data = f.read()
#     355 elif self.url is not None:
#     356     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: './output_Pospischil_sPY/1000nA.png'

# %%
analysis.print_run_stats(pospischilsPY)

# %% [markdown]
# ### Compare with the non-segregated approach

# %%
# Update our config to use the original mod files
pospischilsPY["cell"]["modfiles_folder"] = os.path.join(
    base_dir, "data/Pospischil/sPy/orig_modfiles"
)

# Change the run mode to original (instead of segregated)
pospischilsPY["run_mode"] = "original"

# Re-run

simulator.run(pospischilsPY)

# %%
Image(filename="./output_Pospischil_sPY/original/1000nA.png")

# %%
analysis.print_run_stats(pospischilsPY)
