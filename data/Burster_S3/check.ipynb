# %%
import matplotlib.pyplot as plt

from neuron import h
h.load_file('stdrun.hoc')
# Out:
# 1.0

# %%
h.load_file("orig/template.hoc")
cell = h.Burster()

# %%
cell.soma[0](0.5).cm
# Out:
# 1.0

# %%
# CI
ci = h.IClamp(cell.soma[0](0.5))
ci.amp = 0.1 # (nA)
ci.delay = 50
ci.dur = 150

# V recording
v = h.Vector().record(cell.soma[0](0.5)._ref_v)

# %%
cell.soma[0](0.5).cm
# Out:
# 1.0

# %%
h.tstop = 200
h.dt = 0.1
h.steps_per_ms = 1 / h.dt
h.v_init = -50

# %%
h.run()
# Out:
# 0.0

# %%
plt.plot(v.as_numpy())

# %%
import numpy as np

seg_v = np.load("./seg/seg_check.npy")
orig_v = np.load("./orig/orig_check.npy")

# %%
import matplotlib.pyplot as plt

plt.plot(seg_v, label = 'seg')
plt.plot(orig_v, label = 'orig')
