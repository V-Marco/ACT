# %%
import numpy as np

v_orig = np.load('./orig/orig.npy')
v_seg = np.load('./seg/seg.npy')

# %%
import matplotlib.pyplot as plt

plt.plot(v_orig, label = 'orig')
plt.plot(v_seg, label = 'seg')
plt.legend()

# %%
import numpy as np

mae = np.mean(np.abs(v_orig-v_seg))

print(mae)
# Out:
# 27.864402532535294
