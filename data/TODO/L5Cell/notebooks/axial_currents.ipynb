# %%
import sys
sys.path.append("../")
sys.path.append("../Modules/")

import analysis

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sim_directory = "SkeletonCell.Hay-02-01-2024-21-27-00/try1/"

# %%
v = analysis.DataReader.read_data(sim_directory, "v")
seg_data = pd.read_csv(os.path.join(sim_directory, "segment_data.csv"))

# %%
ac = analysis.CurrentTrace.compute_axial_currents(v, seg_data)
# Out:
# Computing adjacency matrix...
# 100%|██████████| 643/643 [00:14<00:00, 43.69it/s]

# %%
plt.plot(ac[seg_data.section == "dend"].sum(axis = 0))
plt.title = "dend ac"

# %%
plt.plot(ac[seg_data.section == "apic"].sum(axis = 0))
plt.title = "apic ac"
